# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
img = cv2.imread('../binary/normal/100002.jpg')
print(img.shape)
img = cv2.resize(img, (224, 224))
print(img.shape)
plt.imshow(img)
# Out:
# (640, 480, 3)
# (224, 224, 3)

# %%
print(img)
# Out:
# [[[155 207 190]
#   [162 210 198]
#   [123 176 167]
#   ...
#   [ 16 232 197]
#   [ 58 223 196]
#   [ 57 219 193]]
#
#  [[130 184 168]
#   [163 214 201]
#   [144 195 187]
#   ...
#   [ 16 230 195]
#   [ 56 218 192]
#   [ 69 228 202]]
#
#  [[104 172 153]
#   [147 204 190]
#   [148 198 191]
#   ...
#   [ 26 234 200]
#   [ 66 225 199]
#   [ 64 220 195]]
#
#  ...
#
#  [[ 93 184 160]
#   [116 212 191]
#   [ 68 160 144]
#   ...
#   [140 222 200]
#   [146 211 195]
#   [159 214 199]]
#
#  [[ 54 150 118]
#   [ 68 173 143]
#   [100 202 178]
#   ...
#   [105 196 172]
#   [119 215 193]
#   [122 219 197]]
#
#  [[ 49 148 110]
#   [ 39 148 111]
#   [ 31 138 108]
#   ...
#   [ 74 132 114]
#   [ 90 167 148]
#   [101 190 170]]]

# %%
img_flat = img.flatten()
img_reshaped = img_flat.reshape((224, 224, 3))
print(img_reshaped)
plt.imshow(img_reshaped)
# Out:
# [[[155 207 190]
#   [162 210 198]
#   [123 176 167]
#   ...
#   [ 16 232 197]
#   [ 58 223 196]
#   [ 57 219 193]]
#
#  [[130 184 168]
#   [163 214 201]
#   [144 195 187]
#   ...
#   [ 16 230 195]
#   [ 56 218 192]
#   [ 69 228 202]]
#
#  [[104 172 153]
#   [147 204 190]
#   [148 198 191]
#   ...
#   [ 26 234 200]
#   [ 66 225 199]
#   [ 64 220 195]]
#
#  ...
#
#  [[ 93 184 160]
#   [116 212 191]
#   [ 68 160 144]
#   ...
#   [140 222 200]
#   [146 211 195]
#   [159 214 199]]
#
#  [[ 54 150 118]
#   [ 68 173 143]
#   [100 202 178]
#   ...
#   [105 196 172]
#   [119 215 193]
#   [122 219 197]]
#
#  [[ 49 148 110]
#   [ 39 148 111]
#   [ 31 138 108]
#   ...
#   [ 74 132 114]
#   [ 90 167 148]
#   [101 190 170]]]
